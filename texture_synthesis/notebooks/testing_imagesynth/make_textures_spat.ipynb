# %%
from typing import Optional
import argparse
import os
import sys

import torch
import matplotlib.pyplot as plt     # type: ignore

import utilities
import model
import optimize
import pandas as pd

from utils import default_paths

import numpy as np

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

info_fn = os.path.join(default_paths.stim_root, 'Indep_set_info.csv')
print('\nloading image info from %s\n'%info_fn)
info_df = pd.read_csv(info_fn, index_col=0)
# Out:
# cuda
#
# loading image info from /user_data/mmhender/nsd/stimuli/Indep_set_info.csv

# %%
fn_info = os.path.join(os.getcwd(),'vgg19_rfs_info.npy')
rfs_info = np.load(fn_info, allow_pickle=True).item()

# %%
rfs_info.keys()
# Out:
# dict_keys(['pixel_centers', 'layer_unit_centers', 'layer_names_use', 'layer_inds'])

# %%
pixel_centers = rfs_info['pixel_centers']
layer_unit_centers = rfs_info['layer_unit_centers']
layer_names = rfs_info['layer_names_use']
layer_inds = rfs_info['layer_inds']
n_layers = len(layer_names)
n_pix = np.max(pixel_centers)+1

# %%
rfs_each_layer = []
for ll, layer in enumerate(['Conv1','MaxPool1','MaxPool2','MaxPool3','MaxPool4']):
    fn_rfs = os.path.join(os.getcwd(),'vgg19_unit_rfs_%s.npy'%layer)
    rfs = np.load(fn_rfs)
    rfs_each_layer.append(rfs)

# %%
n_grid_eachside=4;
overlap_each_layer = []
for ll in range(n_layers):
    
    fn = os.path.join(os.getcwd(),'vgg19_gridoverlap_%dx%d_%s.npy'%(n_grid_eachside, \
                                                                    n_grid_eachside, layer_names[ll]))
    print(fn)
    overlap = np.load(fn)
    overlap_each_layer.append(overlap)
# Out:
# /user_data/mmhender/toolboxes/texture-synthesis-pytorch/vgg19_gridoverlap_4x4_Conv1.npy
# /user_data/mmhender/toolboxes/texture-synthesis-pytorch/vgg19_gridoverlap_4x4_MaxPool1.npy
# /user_data/mmhender/toolboxes/texture-synthesis-pytorch/vgg19_gridoverlap_4x4_MaxPool2.npy
# /user_data/mmhender/toolboxes/texture-synthesis-pytorch/vgg19_gridoverlap_4x4_MaxPool3.npy
# /user_data/mmhender/toolboxes/texture-synthesis-pytorch/vgg19_gridoverlap_4x4_MaxPool4.npy

# %%
class a():
    def __init__(self, n_ims_do=10, n_steps=10, debug=0):
        self.n_ims_do = n_ims_do
        self.n_steps = n_steps
        self.debug = debug

# %%
args = a()

# %%
ii=0;

print('\nim %d of %d'%(ii, args.n_ims_do))
        
target_image_filename = info_df['filename_raw'].iloc[ii]
print('processing target image %s'%target_image_filename)
sys.stdout.flush()

cocoid = target_image_filename.split('/')[-1].split('.')[0]

out_dir = os.path.join('/user_data/mmhender/stimuli/texture_synth_images', 'coco_%s'%cocoid)
print('will save images to %s'%out_dir)
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

root = os.getcwd()
model_path = os.path.join(root, 'models','VGG19_normalized_avg_pool_pytorch')

args.lr = 1.0
args.max_iter = 20
args.checkpoint_every = 1
if args.debug:
    args.n_steps = 1
args.rndseed = None

# load model & data
target_image = utilities.preprocess_image(
    utilities.load_image(target_image_filename)
)
# Out:
# im 0 of 10
# processing target image /lab_data/tarrlab/common/datasets/COCO/train2017/000000326021.jpg
# will save images to /user_data/mmhender/stimuli/texture_synth_images/coco_000000326021

# %%
important_layers = ['relu1_1', 'pool1','pool2','pool3','pool4']

layers_match = important_layers

net = Model(model_path, device, target_image, important_layers=layers_match, 
                 spatial_weights_list = overlap_each_layer)

# %%
plt.figure()
plt.imshow(result[0,:,:,:].moveaxis([0],[2]).detach().cpu().numpy()/255+0.5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([128, 4096]) torch.Size([4096])
# tensor([0., 0., 0., 0.], device='cuda:0')
# 39 39 tensor(64315.1523, device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([128, 4096]) torch.Size([4096])
# tensor([0., 0., 0., 0.], device='cuda:0')
# 40 40 tensor(9306.4336, device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([128, 4096]) torch.Size([4096])
# tensor([0., 0., 0., 0.], device='cuda:0')
# 41 41 tensor(37160.4844, device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([128, 4096]) torch.Size([4096])
# tensor([0., 0., 0., 0.], device='cuda:0')
# 42 42 tensor(50169.5234, device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([128, 4096]) torch.Size([4096])
# tensor([0., 0., 0., 0.], device='cuda:0')
# 43 43 tensor(61834.0430, device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([128, 4096]) torch.Size([4096])
# tensor([0., 0., 0., 0.], device='cuda:0')
# 44 44 tensor(17386.3438, device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([128, 4096]) torch.Size([4096])
# tensor([0., 0., 0., 0.], device='cuda:0')
# 45 45 tensor(40147.1523, device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([128, 4096]) torch.Size([4096])
# tensor([0., 0., 0., 0.], device='cuda:0')
# 46 46 tensor(34051.2773, device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([128, 4096]) torch.Size([4096])
# tensor([0., 0., 0., 0.], device='cuda:0')
# 47 47 tensor(35204.7773, device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([256, 1024]) torch.Size([1024])
# tensor([1., 1., 1., 1.], device='cuda:0')
# 48 48 tensor(852.4001, device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([256, 1024]) torch.Size([1024])
# tensor([0.0000, 0.0000, 0.0001, 0.0331], device='cuda:0')
# 49 49 tensor(5200.6138, device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([256, 1024]) torch.Size([1024])
# tensor([0., 0., 0., 0.], device='cuda:0')
# 50 50 tensor(10491.2773, device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([256, 1024]) torch.Size([1024])
# tensor([0., 0., 0., 0.], device='cuda:0')
# 51 51 tensor(7264.7520, device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([256, 1024]) torch.Size([1024])
# tensor([0., 0., 0., 0.], device='cuda:0')
# 52 52 tensor(1553.9631, device='cuda:0', grad_fn=<MulBackward0>)
# computing spatially weighted gram matrix
# torch.Size([256, 1024]) torch.Size([1024])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-119-addcdf7002fa> in <module>
#       1 # synthesize
#       2 optimizer = optimize.Optimizer(net, args)
# ----> 3 result = optimizer.optimize()
#
# /user_data/mmhender/toolboxes/texture-synthesis-pytorch/optimize.py in optimize(self)
#      62                 return loss
#      63
# ---> 64             optimizer.step(closure)
#      65
#      66             if step % self.checkpoint_every == self.checkpoint_every - 1:
#
# ~/myenv/lib/python3.7/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     111                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     112                 with torch.autograd.profiler.record_function(profile_name):
# --> 113                     return func(*args, **kwargs)
#     114             return wrapper
#     115
#
# ~/myenv/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/myenv/lib/python3.7/site-packages/torch/optim/lbfgs.py in step(self, closure)
#     424
#     425                     loss, flat_grad, t, ls_func_evals = _strong_wolfe(
# --> 426                         obj_func, x_init, t, d, loss, flat_grad, gtd)
#     427                 self._add_grad(t, d)
#     428                 opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# ~/myenv/lib/python3.7/site-packages/torch/optim/lbfgs.py in _strong_wolfe(obj_func, x, t, d, f, g, gtd, c1, c2, tolerance_change, max_ls)
#      47     g = g.clone(memory_format=torch.contiguous_format)
#      48     # evaluate objective and gradient using initial step
# ---> 49     f_new, g_new = obj_func(x, t, d)
#      50     ls_func_evals = 1
#      51     gtd_new = g_new.dot(d)
#
# ~/myenv/lib/python3.7/site-packages/torch/optim/lbfgs.py in obj_func(x, t, d)
#     421
#     422                     def obj_func(x, t, d):
# --> 423                         return self._directional_evaluate(closure, x, t, d)
#     424
#     425                     loss, flat_grad, t, ls_func_evals = _strong_wolfe(
#
# ~/myenv/lib/python3.7/site-packages/torch/optim/lbfgs.py in _directional_evaluate(self, closure, x, t, d)
#     275     def _directional_evaluate(self, closure, x, t, d):
#     276         self._add_grad(t, d)
# --> 277         loss = float(closure())
#     278         flat_grad = self._gather_flat_grad()
#     279         self._set_param(x)
#
# ~/myenv/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /user_data/mmhender/toolboxes/texture-synthesis-pytorch/optimize.py in closure()
#      56             def closure():
#      57                 optimizer.zero_grad()
# ---> 58                 self.model(self.reparam_func(self.opt_image))
#      59                 loss = self.model.get_loss()
#      60                 loss.backward()
#
# <ipython-input-112-03f0a603afc5> in __call__(self, image)
#      85         self.gram_loss_hook.clear()
#      86
# ---> 87         return self.net(image)
#      88
#      89     def get_loss(self) -> torch.Tensor:
#
# ~/myenv/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# <string> in forward(self, input)
#
# ~/myenv/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1149         if _global_forward_hooks or self._forward_hooks:
#    1150             for hook in (*_global_forward_hooks.values(), *self._forward_hooks.values()):
# -> 1151                 hook_result = hook(self, input, result)
#    1152                 if hook_result is not None:
#    1153                     result = hook_result
#
# <ipython-input-112-03f0a603afc5> in __call__(self, layer, layer_in, layer_out)
#     148             # print(ll, gg, tt)
#     149             opt_gram_matrix = gram_matrix_spatweighted(layer_out,
# --> 150                                                        self.spatial_weights_list[ll][gg,:])
#     151
#     152             # print(opt_gram_matrix.shape)
#
# <ipython-input-112-03f0a603afc5> in gram_matrix_spatweighted(activations, spatial_weights)
#      13     print('computing spatially weighted gram matrix')
#      14     print(activation_matrix.shape, spatial_weights.shape)
# ---> 15     print(spatial_weights[0:4])
#      16     activation_matrix_weighted = activation_matrix * torch.sqrt(spatial_weights[None,:])
#      17
#
# ~/myenv/lib/python3.7/site-packages/torch/_tensor.py in __repr__(self, tensor_contents)
#     336                                          tensor_contents=tensor_contents)
#     337         # All strings are unicode in Python 3.
# --> 338         return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#     339
#     340     def backward(self, gradient=None, retain_graph=None, create_graph=False, inputs=None):
#
# ~/myenv/lib/python3.7/site-packages/torch/_tensor_str.py in _str(self, tensor_contents)
#     479 def _str(self, *, tensor_contents=None):
#     480     with torch.no_grad():
# --> 481         return _str_intern(self, tensor_contents=tensor_contents)
#
# ~/myenv/lib/python3.7/site-packages/torch/_tensor_str.py in _str_intern(inp, tensor_contents)
#     445                         tensor_str = _tensor_str(self.to_dense(), indent)
#     446                     else:
# --> 447                         tensor_str = _tensor_str(self, indent)
#     448
#     449     if self.layout != torch.strided:
#
# ~/myenv/lib/python3.7/site-packages/torch/_tensor_str.py in _tensor_str(self, indent)
#     248     summarize = self.numel() > PRINT_OPTS.threshold
#     249
# --> 250     if self._is_zerotensor():
#     251         self = self.clone()
#     252
#
# KeyboardInterrupt:

# %%
from typing import List, Tuple

import torch

import utilities


def gram_matrix_spatweighted(activations: torch.Tensor, spatial_weights: torch.Tensor = None) -> torch.Tensor:
    b, n, x, y = activations.size()
    # print((b,n,x,y))
    activation_matrix = activations.view(b * n, x * y)
    
    print('computing spatially weighted gram matrix')
    print(activation_matrix.shape, spatial_weights.shape)
    print(spatial_weights[0:4])
    activation_matrix_weighted = activation_matrix * torch.sqrt(spatial_weights[None,:])
    
    G = torch.mm(activation_matrix_weighted, activation_matrix_weighted.t())    # gram product
    return G.div(b * n * x * y)     # normalization


class Model:
    def __init__(
        self, path: str, device: torch.device, target_image: torch.Tensor,
        layer_weights: List[float] = [1e09, 1e09, 1e09, 1e09, 1e09],
        important_layers: List[str] = [
            'relu1_1', 'pool1', 'pool2', 'pool3', 'pool4'
        ],
        spatial_weights_list: List[torch.Tensor] = None,
    ):
        self.net = utilities.load_model(path).to(device).eval()
        self.device = device
        self.target_image = target_image.to(device)
        self.layer_weights = layer_weights
        self.important_layers = important_layers
        # print(self.important_layers)
        
        self.spatial_weights_list = [torch.Tensor(sw).to(self.device) for sw in spatial_weights_list]
        if self.spatial_weights_list is not None:
            self.n_total_grid = self.spatial_weights_list[0].shape[0]
            assert(len(self.spatial_weights_list)==len(self.important_layers))
            
        # extract Gram matrices of the target image
        
        gram_hook = GramHook(self.spatial_weights_list)
        gram_hook_handles = []
        
        for name, layer in self.net.named_children():
            if name in self.important_layers:
               
                handle = layer.register_forward_hook(gram_hook)
                gram_hook_handles.append(handle)
            
        self.net(self.target_image)

        # print('gram matrices:')
        # print(len(gram_hook.gram_matrices), [gm.shape for gm in gram_hook.gram_matrices])
        # register Gram loss hook
        self.gram_loss_hook = GramLossHook(
            gram_hook.gram_matrices, self.layer_weights, \
            self.important_layers, self.spatial_weights_list,
        )
        # print('sizes of gram matrices')
        # for ii, mat in enumerate(gram_hook.gram_matrices):
        #     print(ii, mat.shape)
        for handle in gram_hook_handles:    # Gram hook is not needed anymore
            handle.remove()

        for name, layer in self.net.named_children():
            if name in self.important_layers:
                # print('adding loss hook for %s'%name)
                handle = layer.register_forward_hook(self.gram_loss_hook)

        # print([name for [name, l] in self.net.named_children()])
        # remove unnecessary layers
        i = 0
        for name, layer in self.net.named_children():
            if name == important_layers[-1]:
                break
            i += 1
        self.net = self.net[:(i + 1)]
        # print([name for [name, l] in self.net.named_children()])
        
    def __call__(self, image: torch.Tensor) -> torch.Tensor:
        self.gram_loss_hook.clear()

        return self.net(image)

    def get_loss(self) -> torch.Tensor:
        # return sum(self.gram_loss_hook.losses)
        return torch.stack(self.gram_loss_hook.losses, dim=0).sum(dim=0)

    
class GramHook:
    def __init__(self, 
                 spatial_weights_list: List[torch.Tensor]):
        self.gram_matrices = []
        self.spatial_weights_list = spatial_weights_list
        self.layer_counter = -1;
        
    def __call__(
        self, layer: torch.nn.Module, layer_in: Tuple[torch.Tensor],
        layer_out: torch.Tensor
    ):
        self.layer_counter+=1
        ll = self.layer_counter
        n_grid_total = self.spatial_weights_list[0].shape[0]
        for gg in range(n_grid_total):
            spatial_weights = self.spatial_weights_list[ll][gg,:]
            # print('size of spatial weights:')
            # print(spatial_weights.shape)
            gram_matrix = gram_matrix_spatweighted(layer_out.detach(), spatial_weights)
            # print('size of gram matrix:')
            # print(gram_matrix.shape)
            self.gram_matrices.append(gram_matrix)

class GramLossHook:
    def __init__(
        self, target_gram_matrices: List[torch.Tensor],
        layer_weights: List[float], layer_names: List[str],
        spatial_weights_list: List[torch.Tensor],
    ):
        self.target_gram_matrices = target_gram_matrices
        self.layer_weights = [
            weight * (1.0 / 4.0) for weight in layer_weights
        ]
        self.layer_names = layer_names
        self.losses: List[torch.Tensor] = []
        self.spatial_weights_list = spatial_weights_list
        self.layer_counter = -1;
        
    def __call__(
        self, layer: torch.nn.Module, layer_in: Tuple[torch.Tensor],
        layer_out: torch.Tensor
    ):
        self.layer_counter+=1
        ll = self.layer_counter
        # print('layer_counter = %d'%self.layer_counter)
        assert ll < len(self.layer_weights)
        assert ll < len(self.target_gram_matrices)
        assert not torch.isnan(layer_out).any()

        n_grid_total = self.spatial_weights_list[0].shape[0]
        for gg in range(n_grid_total):
            # print('len of layer_names: %d'%len(self.layer_names))
            
            tt = ll * n_grid_total + gg
            # print(ll, gg, tt)
            opt_gram_matrix = gram_matrix_spatweighted(layer_out, 
                                                       self.spatial_weights_list[ll][gg,:])
            
            # print(opt_gram_matrix.shape)
            # print(self.target_gram_matrices[tt].shape)
            loss = self.layer_weights[ll] * (
                (opt_gram_matrix - self.target_gram_matrices[tt])**2
            ).sum()
            print(tt, len(self.losses), loss)
            self.losses.append(loss)

    def clear(self):
        self.losses = []
        self.layer_counter=-1
