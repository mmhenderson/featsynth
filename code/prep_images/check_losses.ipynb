# %%
import sys, os
import numpy as np

import PIL
import matplotlib.pyplot as plt

import pandas as pd

# %%
sys.path.append('/user_data/mmhender/featsynth/texture_synthesis/code/')
import make_featsynth_images_comb64
# make_featsynth_images_comb64.proc_synth_losses()

# %%
ecoset_info_path = '/user_data/mmhender/stimuli/ecoset_info/'
save_stim_path = '/user_data/mmhender/stimuli/featsynth/images_comb64'

fn = os.path.join(ecoset_info_path, 'categ_use_ecoset.npy')
info = np.load(fn, allow_pickle=True).item()
bnames = list(info['binfo'].keys())


fn = '/user_data/mmhender/stimuli/featsynth/images_comb64/synth_losses_all.npy'
print(fn)
l = np.load(fn, allow_pickle=True).item()
# Out:
# /user_data/mmhender/stimuli/featsynth/images_comb64/synth_losses_all.npy

# %%
# # for bi in np.arange(32, 40):
# bi = 32;
    
# bname = bnames[bi]

# ex_sorted = l[bname]['order']

# layers = ['pool1','pool2','pool3','pool4']  

# best_ex = ex_sorted[0:1]

# # worst_ex = ex_sorted[38:]

# # for ex_list, which_name in zip([best_ex, worst_ex], ['best','worst']):
    
# for ee in best_ex:

#     image_path = os.path.join(save_stim_path, bname, 'ex%02d'%ee)

#     names = ['orig.png']
    
#     names += ['scramble_upto_%s.png'%layers[li] for li in [0, 1]]

#     pi=0;

#     plt.figure(figsize=(12,6))
    
#     for ni, name in enumerate(names):
            
#         imfn = os.path.join(image_path, name)
#         im = PIL.Image.open(imfn) 

#         pi+=1
#         plt.subplot(1,3,pi)

#         plt.imshow(im)
#         plt.axis('off')

#     plt.suptitle('%s: ex %d'%(bname, ee))

# %%
# for bi in np.arange(32, 33):

    
#     bname = bnames[bi]
    
#     ex_sorted = l[bname]['order']
    
#     layers = ['pool1','pool2','pool3','pool4']  
#     li = 0;
      
#     loss_vals = l[bname]['loss_%s'%(layers[li])]
    
#     best_ex = ex_sorted[0:1]
#     worst_ex = ex_sorted[38:]
    
#     for ex_list, which_name in zip([best_ex, worst_ex], ['best','worst']):
            
#         for ee in ex_list:
        
#             image_path = os.path.join(save_stim_path, bname, 'ex%02d'%ee)
        
#             names = ['orig.png']
            
#             names += ['scramble_upto_%s.png'%layers[li] for li in [li]]
        
#             pi=0;
        
#             plt.figure(figsize=(12,6))
            
#             for ni, name in enumerate(names):
                    
#                 imfn = os.path.join(image_path, name)
#                 im = PIL.Image.open(imfn) 
        
#                 pi+=1
#                 plt.subplot(1,2,pi)
        
#                 plt.imshow(im)
#                 plt.axis('off')
        
#             plt.suptitle('%s %s: %s loss = %.5f'%(which_name, bname, layers[li], loss_vals[ee]))

# %%
# # for bi in np.arange(32, 40):
# for bi in np.arange(40, 44):
        
#     bname = bnames[bi]
        
#     ex_sorted = l[bname]['order']

#     ex_list = ex_sorted[0:35]
#     # ex_list = ex_sorted[0:2]

#     layers = ['pool1','pool2','pool3','pool4']  
    
#     for ei, ee in enumerate(ex_list):
    
#         image_path = os.path.join(save_stim_path, bname, 'ex%02d'%ee)
    
#         names = ['orig.png']
#         names += ['scramble_upto_%s.png'%layers[li] for li in range(4)]
    
#         pi=0;
    
#         plt.figure(figsize=(12,8))
        
#         for ni, name in enumerate(names):
                
#             imfn = os.path.join(image_path, name)
#             im = PIL.Image.open(imfn) 
    
#             pi+=1
#             plt.subplot(2,3,pi)
    
#             plt.imshow(im)
#             plt.axis('off')
    
#         plt.suptitle('%s: rank %d'%(bname, ei))
