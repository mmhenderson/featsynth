# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os, sys
from datetime import datetime, timedelta

# %%
project_root = '/user_data/mmhender/featsynth/'

expt_name = 'pilot4'

data_folder = os.path.join(project_root, 'online_data', expt_name)
expt_design_folder = os.path.join(project_root, 'expt_design', expt_name)

preproc_folder = os.path.join(data_folder, 'preproc')
if not os.path.exists(preproc_folder):
    os.makedirs(preproc_folder)
    
folders = os.listdir(data_folder)
folders = [f for f in folders if os.path.isdir(os.path.join(data_folder,f))]
folders = [f for f in folders if 'data' in f and 'old' not in f]
# folders = [folders[0]]
folders
# Out:
# ['data_exp_113782-v4']

# %%
raw_data = pd.DataFrame()
raw_worker_ids = pd.DataFrame()

for ff, folder in enumerate(folders):
    
    string1 = 'task'
    subfolder = os.path.join(data_folder, folders[ff])
    files = os.listdir(subfolder)
    files = [f for f in files if string1 in f and '.csv' in f]
    task_filename = os.path.join(subfolder,files[0])
    print(task_filename)

    r = pd.read_csv(task_filename)
    raw_data = pd.concat([raw_data, r])
    
    
    string2 = '89gk'
    subfolder = os.path.join(data_folder, folders[ff])
    files = os.listdir(subfolder)
    files = [f for f in files if string2 in f and '.csv' in f]
    if len(files)>0:
        worker_id_filename = os.path.join(subfolder,files[0])
        r = pd.read_csv(worker_id_filename)
        raw_worker_ids = pd.concat([raw_worker_ids, r])
    
raw_data.set_index(np.arange(raw_data.shape[0]));
raw_worker_ids.set_index(np.arange(raw_worker_ids.shape[0]));
# Out:
# /user_data/mmhender/featsynth/online_data/pilot4/data_exp_113782-v4/data_exp_113782-v4_task-sq8b.csv
# /home/mmhender/imstat_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
public_ids = np.array(raw_data['Participant Public ID'])
public_ids = [p if isinstance(p,str) else '' for p in public_ids]
public_ids = np.unique(public_ids)
public_ids = np.array([p for p in public_ids if len(p)>1])

is_good = []
for pub_id in public_ids:
    inds = np.where(raw_data['Participant Public ID']==pub_id)[0]
    d = raw_data.iloc[inds]
    
    code = np.array(d['Participant Completion Code'])
    has_code = np.any([isinstance(c,str) for c in code])
    
    is_good += [has_code]

# %%
time_format_str = '%d/%m/%Y %H:%M:%S'

def adjust_datetime_str(date_str, time_format_str, hours):
    date_num = datetime.strptime(date_str, time_format_str)
    date_num_adj = date_num + timedelta(hours=-8)
    date_str_adj = datetime.strftime(date_num_adj,  time_format_str)
    return date_str_adj

def make_subject_df(public_ids):

    colnames = ['Gorilla public ID', 'Survey Completion Code', \
                'Worker ID mTurk',\
                'Expt Start Time (PST)', 'Expt End Time (PST)', 'Total number of trials', \
               'Experiment version num', 'Task version num']

    df = pd.DataFrame(columns=colnames)

    for ii, pub_id in enumerate(public_ids):

        inds = np.where(raw_data['Participant Public ID']==pub_id)[0]

        d = raw_data.iloc[inds]

        trial_nums = np.array(d['trial_in_run'])
        trial_nums = trial_nums[~np.isnan(trial_nums)]
        n_trials = int(len(trial_nums)/3)

        code = np.array(d['Participant Completion Code'])[0]

        # converting to PST here
        start = adjust_datetime_str(np.min(d['UTC Date']), time_format_str, -8)
        end = adjust_datetime_str(np.max(d['UTC Date']), time_format_str, -8)

        subject_inds = [pub_id==pid for pid in raw_worker_ids['Participant Public ID']]
        if sum(subject_inds)>0:
            inds = np.where(subject_inds & (raw_worker_ids['Question Key']=='worker-id'))[0][0]
            wid = raw_worker_ids['Response'].iloc[inds]
        else:
            wid = 'nan'

        task_version = np.array(d['Task Version'])[0]
        expt_version = np.array(d['Experiment Version'])[0]

        vals = np.array([[pub_id, code, wid, start, end, n_trials, expt_version, task_version]])
        df = pd.concat([df, pd.DataFrame(vals, columns=colnames, index=[ii])],\
                        axis=0)
    return df

# %% [markdown]
# #### Print complete subjects

# %%
good_ids = public_ids[np.array(is_good)]
good_df = make_subject_df(good_ids)
fn2save = os.path.join(preproc_folder,'good_sub_list.csv')
good_df.to_csv(fn2save)
# sort_order = np.argsort(np.array(good_df['Expt End Time (PST)']))
sort_order = np.argsort(np.array(good_df['Expt Start Time (PST)']))
# good_df.iloc[sort_order]
good_df
# Out:
#    Gorilla public ID Survey Completion Code Worker ID mTurk  \
# 0           0q0shv3m                 ifgqoo   AZ69TBTDH7AZS
# 1           15owyc9p                 wpbzbv   AND64IJKXZZMG
# 2           1aw5gys2                 fsxsiz  A2YC6PEMIRSOAA
# 3           1ql190pa                 scplmj  A354LBXNXIKTKN
# 4           2wny9ec4                 oyvshm  A2F5SKVBQQXFX0
# 5           380cpo0y                 nlposs   AMCT1XHLT5I1M
# 6           6g49pnz7                 icvwsg   AF318MABD1U0S
# 7           6swid0id                 hpiimu  A256FHXGSY0E5D
# 8           7vtju91h                 txwlud  A2MWAXV1YRK5GH
# 9           9mjm77fg                 mcskel  A2V27A9GZA1NR2
# 10          al9pm59q                 vpsakj  A2NIZYRZHTXTM2
# 11          at945kvt                 wvcmht  A1FN26YO82OW51
# 12          bhd9it6f                 cebtyb  A20UPI9DKK3X72
# 13          bpr0qdsv                 jypgnw  A3352396Q2YDRV
# 14          btc8zumv                 lwdevd  A2APG8MSLJ6G2K
# 15          cf5j8qak                 nqamgm  A2M183CETUMR96
# 16          cs36fwwf                 jimopt   AIRCO7SHVNCS2
# 17          dlrwfrmj                 xyjhaz   AHTCV3M88WJWB
# 18          gmbze47f                 nxufer   ARAZS0EU2QIBI
# 19          gvfnxm1l                 ranbvs  A3HE8B51AK8TET
# 20          hiw0y77i                 qhtnfw  A3E85JBWPSBQEO
# 21          i163wruc                 wriamb  A16335MOISDG1F
# 22          ibptgp2w                 svnenu  A25DP004MRTP05
# 23          iuvswbcx                 ccizcs  A3KYYRZCF37KWR
# 24          iux5w4wx                 qeylzb   AXAO7UJYYEFCO
# 25          ixs44ht9                 fqmpid  A1G6UEWWEKUB9V
# 26          j5q7qpsk                 mmnvdc  A3TWLUDVUZPQ8Z
# 27          ktc83wd6                 omxdil  A3DW6KSQPG6GVQ
# 28          lbfs1h70                 tfokqe   AA4O2W236E3FW
# 29          nms43bnl                 lavwcv  A2HL825K192I9Y
# 30          p5dfexpc                 jaqrnh  A1KBDN6C1Q0D4U
# 31          p5vspv69                 dpcyzu  A2WPKP73S4MBLK
# 32          qqh1odxa                 zfkkxs   AADBSWVO7D3X8
# 33          sqrirtq7                 nsstyr  A26M997VYVK0E6
# 34          u6ta5l81                 jpzqvz   A80OY90TZSD8F
# 35          x7gqyr98                 wbalpj  A3L1TCVTUPWKYS
# 36          yg8nw4dz                 xwurbb   ARR9GKAG3JFE5
# 37          zw6ohjae                 dujasj  A3FE4TVFPIX53P
#
#    Expt Start Time (PST)  Expt End Time (PST) Total number of trials  \
# 0    26/01/2023 18:06:24  26/01/2023 19:04:32                   1000
# 1    21/01/2023 11:53:53  21/01/2023 13:24:07                   1000
# 2    19/01/2023 09:57:20  19/01/2023 10:59:27                   1000
# 3    21/01/2023 16:01:03  21/01/2023 16:57:41                   1000
# 4    21/01/2023 12:35:33  21/01/2023 13:32:54                   1000
# 5    26/01/2023 17:19:32  26/01/2023 18:26:30                   1000
# 6    27/01/2023 10:33:45  27/01/2023 11:32:01                   1000
# 7    19/01/2023 10:09:34  19/01/2023 11:08:23                   1000
# 8    19/01/2023 10:24:02  19/01/2023 11:36:16                   1000
# 9    27/01/2023 10:28:22  27/01/2023 12:55:19                   1000
# 10   26/01/2023 15:09:46  26/01/2023 16:19:16                   1000
# 11   21/01/2023 12:56:04  21/01/2023 13:53:52                   1000
# 12   21/01/2023 11:53:05  21/01/2023 12:51:00                   1000
# 13   19/01/2023 12:00:15  19/01/2023 13:23:22                   1000
# 14   19/01/2023 10:23:35  19/01/2023 11:22:01                   1000
# 15   26/01/2023 15:35:28  26/01/2023 16:36:43                   1000
# 16   21/01/2023 15:00:14  21/01/2023 15:58:11                   1000
# 17   27/01/2023 10:24:33  27/01/2023 11:41:21                   1000
# 18   27/01/2023 11:50:18  27/01/2023 19:45:28                   1000
# 19   19/01/2023 12:09:00  19/01/2023 13:44:31                   1000
# 20   19/01/2023 09:58:00  19/01/2023 10:54:46                   1000
# 21   26/01/2023 15:10:03  26/01/2023 16:07:49                   1000
# 22   21/01/2023 12:00:28  21/01/2023 13:05:11                   1000
# 23   21/01/2023 12:35:47  21/01/2023 13:33:56                   1000
# 24   26/01/2023 17:19:42  26/01/2023 18:19:35                   1000
# 25   21/01/2023 14:27:21  21/01/2023 15:23:57                   1000
# 26   26/01/2023 17:11:23  26/01/2023 18:14:58                   1000
# 27   19/01/2023 10:11:11  19/01/2023 11:08:56                   1000
# 28   19/01/2023 10:40:17  19/01/2023 11:39:56                   1000
# 29   21/01/2023 12:04:38  21/01/2023 13:05:07                   1000
# 30   19/01/2023 13:06:46  19/01/2023 14:09:51                   1000
# 31   27/01/2023 11:05:40  27/01/2023 12:05:54                   1000
# 32   21/01/2023 11:54:25  21/01/2023 12:56:38                   1000
# 33   27/01/2023 10:33:07  27/01/2023 11:33:04                   1000
# 34   28/01/2023 05:24:22  28/01/2023 06:31:34                   1000
# 35   27/01/2023 10:27:40  27/01/2023 11:27:12                   1000
# 36   27/01/2023 10:42:01  27/01/2023 11:43:23                   1000
# 37   21/01/2023 11:54:29  21/01/2023 12:52:16                   1000
#
#    Experiment version num Task version num
# 0                     4.0              1.0
# 1                     4.0              1.0
# 2                     4.0              1.0
# 3                     4.0              1.0
# 4                     4.0              1.0
# 5                     4.0              1.0
# 6                     4.0              1.0
# 7                     4.0              1.0
# 8                     4.0              1.0
# 9                     4.0              1.0
# 10                    4.0              1.0
# 11                    4.0              1.0
# 12                    4.0              1.0
# 13                    4.0              1.0
# 14                    4.0              1.0
# 15                    4.0              1.0
# 16                    4.0              1.0
# 17                    4.0              1.0
# 18                    4.0              1.0
# 19                    4.0              1.0
# 20                    4.0              1.0
# 21                    4.0              1.0
# 22                    4.0              1.0
# 23                    4.0              1.0
# 24                    4.0              1.0
# 25                    4.0              1.0
# 26                    4.0              1.0
# 27                    4.0              1.0
# 28                    4.0              1.0
# 29                    4.0              1.0
# 30                    4.0              1.0
# 31                    4.0              1.0
# 32                    4.0              1.0
# 33                    4.0              1.0
# 34                    4.0              1.0
# 35                    4.0              1.0
# 36                    4.0              1.0
# 37                    4.0              1.0

# %% [markdown]
# #### Print incomplete subjects

# %%
incomplete_ids = public_ids[~np.array(is_good)]
incomplete_df = make_subject_df(incomplete_ids)
fn2save = os.path.join(preproc_folder,'incomplete_sub_list.csv')
incomplete_df.to_csv(fn2save)
incomplete_df
# Out:
#   Gorilla public ID Survey Completion Code Worker ID mTurk  \
# 0          ucat4e0x                    nan  A2NAKIXS3DVGAA
#
#   Expt Start Time (PST)  Expt End Time (PST) Total number of trials  \
# 0   19/01/2023 09:58:25  19/01/2023 10:31:00                    500
#
#   Experiment version num Task version num
# 0                    4.0              1.0

# %%
super_names_eachset = []
basic_names_eachset = []

for which_cb in [1,2]:
    info_filename = os.path.join(expt_design_folder, 'trial_info_counterbal%d.csv'%which_cb)
    info = pd.read_csv(info_filename)
    
    super_names = np.unique(info['super_name'])
    basic_names = []
    for sup in super_names:
        basic = np.unique(np.array(info['basic_name'][info['super_name']==sup]))
        basic_names += [basic]
        
    super_names_eachset += [super_names]    
    basic_names_eachset += [basic_names]
    
n_supcat = len(super_names_eachset[0])
n_bascat = len(basic_names_eachset[0][0])
n_supcat, n_bascat
# Out:
# (10, 10)

# %%
def preproc_data(data):
    
    start_run_inds = np.where(~np.isnan(data['subject_id_rnd']))[0][0::2]
    stop_run_inds = np.where(~np.isnan(data['subject_id_rnd']))[0][1::2]
    finish_inds = stop_run_inds+1

    # print(data.shape)
    # print(finish_inds)
    run_acc = np.array(data['total_acc'])[finish_inds]
    run_avg_rts = np.array(data['average_rt'])[finish_inds]
    print('run accuracies, avg RTs:')
    print(run_acc, run_avg_rts)
    
    run_numbers = np.array(data['run_number'])[start_run_inds].astype(int)
   
    which_cb = int(np.array(data['which_counterbal'])[start_run_inds[0]])
    # which_cb = 1
    print(which_cb)
    
    info_filename = os.path.join(expt_design_folder, 'trial_info_counterbal%d.csv'%which_cb)
    info = pd.read_csv(info_filename)

    n_trials = np.sum(data['is_stim'])
    assert(info.shape[0]==n_trials)

    trial_data = info
    rts = np.array(data['Reaction Time'])
    stim_rts = rts[data['is_stim']==True]
    iti_rts = rts[data['is_iti']==True]

    trial_data['run_number'] = np.repeat(run_numbers, int(n_trials/len(run_numbers)))
    
    stimulus_dur_ms = 300

    rts = stim_rts
    rts[np.isnan(stim_rts)] = iti_rts[np.isnan(stim_rts)] + stimulus_dur_ms

    trial_data['rt'] = rts

    resp = np.array(proc_resp_strs(data['Response']))

    stim_resp = resp[data['is_stim']==True]
    iti_resp = resp[data['is_iti']==True]
    resp = stim_resp
    resp[np.isnan(stim_resp)] = iti_resp[np.isnan(stim_resp)]

    resp[np.isnan(resp)] = -1
    trial_data['resp'] = resp.astype(int)

    correct_resp = np.array(data['correct_response'])
    correct_resp = correct_resp[data['is_stim']==True].astype(int)

    # double check that trial sequence is correct between data and trial info csv
    correct_resp_check = 2-info['target_present'].astype(int)
    # print(correct_resp_check, correct_resp)
    # print(correct_resp_check==correct_resp)
    # print(np.where(~(correct_resp_check==correct_resp)))
    assert(np.all(correct_resp_check==correct_resp))

    trial_data['correct_resp'] = correct_resp

    trial_data['correct'] = trial_data['correct_resp']==trial_data['resp']

    return trial_data, info

def proc_resp_strs(resp, poss_resp = ['1','2']):

    resp = [r if isinstance(r, str) else str(r) for r in resp]
    proc_resp = np.array([int(r) if r in poss_resp else np.nan for r in resp])

    return proc_resp

# %%
subject_ids = good_ids
n_subjects = len(subject_ids)

# %%
subject_ids.shape
# Out:
# (38,)

# %%
trial_data_all = pd.DataFrame()
good_subject_count = 0
for si, ss in enumerate(subject_ids):

    inds = np.where(raw_data['Participant Public ID']==ss)[0]
    d = raw_data.iloc[inds,:]
    
    # sort by time. sometimes they are out of order, sometimes not...
    t = d['Local Timestamp']
    
    d = d.iloc[np.argsort(t)]
    
    which_cb = np.array(d['which_counterbal'])
    which_cb = int(which_cb[~np.isnan(which_cb)][0])

    pub_id = np.array(d['Participant Public ID'])[0]
    print('\nsubject %d, id: %s'%(si, pub_id))
    print('counterbalance cond: %d'%which_cb)
    
    trial_data, info = preproc_data(d)
    
    # as quality control, check accuracy on the intact condition. subjects
    # should all be above 0.50 on this since it's easy.
    intact_data = trial_data[trial_data['image_type']=='orig']
    intact_acc = np.mean(intact_data['resp']==intact_data['correct_resp'])

    print('intact acc: %.2f'%intact_acc)
    if intact_acc<0.50:
        
        print('skipping this subject')
        continue
        
    else:
        
        good_subject_count += 1
        trial_data['subject']=np.full(fill_value=good_subject_count, shape=[trial_data.shape[0],])

        trial_data['which_cb']=np.full(fill_value=which_cb, shape=[trial_data.shape[0],])
        trial_data['gorilla_pub_id']=np.full(fill_value=ss, shape=[trial_data.shape[0],])
        trial_data['worker_id']=np.full(fill_value=good_df['Worker ID mTurk'].iloc[si], shape=[trial_data.shape[0],])

        trial_data_all = pd.concat([trial_data_all, trial_data])
    
trial_data_all.set_index(np.arange(trial_data_all.shape[0]));
fn2save = os.path.join(preproc_folder, 'preproc_data_all.csv')
trial_data_all.to_csv(fn2save)
# Out:
# subject 0, id: 0q0shv3m
# counterbalance cond: 2
# run accuracies, avg RTs:
# [68. 73. 62. 69. 65. 66. 61. 71. 64. 68.] [603. 616. 575. 576. 642. 671. 657. 635. 646. 618.]
# 2
# intact acc: 0.80
#
# subject 1, id: 15owyc9p
# counterbalance cond: 1
# run accuracies, avg RTs:
# [64. 60. 61. 64. 65. 63. 66. 64. 55. 55.] [1014.  920. 1023. 1013.  918.  961.  903.  912.  872.  967.]
# 1
# intact acc: 0.73
#
# subject 2, id: 1aw5gys2
# counterbalance cond: 1
# run accuracies, avg RTs:
# [69. 71. 75. 73. 75. 83. 77. 71. 70. 71.] [ 836.  904. 1027.  835.  814.  882.  937.  958.  958.  900.]
# 1
# intact acc: 0.88
#
# subject 3, id: 1ql190pa
# counterbalance cond: 1
# run accuracies, avg RTs:
# [52. 50. 44. 54. 40. 42. 35. 50. 52. 51.] [467. 523. 505. 555. 568. 468. 580. 787. 878. 779.]
# 1
# intact acc: 0.43
# skipping this subject
#
# subject 4, id: 2wny9ec4
# counterbalance cond: 2
# run accuracies, avg RTs:
# [51. 43. 34. 43. 43. 42. 43. 43. 42. 46.] [880. 710. 857. 979. 832. 824. 881. 800. 828. 844.]
# 2
# intact acc: 0.42
# skipping this subject
#
# subject 5, id: 380cpo0y
# counterbalance cond: 2
# run accuracies, avg RTs:
# [31. 57. 46. 48. 44. 51. 48. 46. 49. 52.] [585. 202. 335. 355. 600. 587. 596. 544. 573. 568.]
# 2
# intact acc: 0.48
# skipping this subject
#
# subject 6, id: 6g49pnz7
# counterbalance cond: 2
# run accuracies, avg RTs:
# [58. 71. 56. 57. 59. 46. 65. 53. 65. 55.] [1158.  995.  843.  865.  851.  843.  774.  788.  740.  742.]
# 2
# intact acc: 0.64
#
# subject 7, id: 6swid0id
# counterbalance cond: 2
# run accuracies, avg RTs:
# [70. 75. 69. 77. 76. 75. 80. 80. 67. 80.] [599. 529. 539. 500. 505. 515. 471. 499. 475. 479.]
# 2
# intact acc: 0.83
#
# subject 8, id: 7vtju91h
# counterbalance cond: 1
# run accuracies, avg RTs:
# [79. 75. 91. 83. 85. 91. 88. 81. 81. 85.] [ 951. 1063. 1031. 1059. 1077.  998.  836.  985.  993.  923.]
# 1
# intact acc: 0.96
#
# subject 9, id: 9mjm77fg
# counterbalance cond: 2
# run accuracies, avg RTs:
# [77. 82. 69. 88. 80. 83. 79. 83. 25. 79.] [684. 651. 645. 650. 665. 630. 682. 701. 677. 687.]
# 2
# intact acc: 0.88
#
# subject 10, id: al9pm59q
# counterbalance cond: 1
# run accuracies, avg RTs:
# [56. 54. 55. 66. 60. 49. 42. 51. 21. 53.] [857. 922. 943. 882. 868. 672. 749. 717. 689. 676.]
# 1
# intact acc: 0.52
#
# subject 11, id: at945kvt
# counterbalance cond: 1
# run accuracies, avg RTs:
# [55. 65. 57. 58. 56. 54. 61. 53. 52. 36.] [1321. 1170. 1321. 1278. 1223. 1245. 1256. 1169. 1088.  362.]
# 1
# intact acc: 0.61
#
# subject 12, id: bhd9it6f
# counterbalance cond: 1
# run accuracies, avg RTs:
# [56. 49. 58. 49. 55. 52. 52. 47. 44. 44.] [1197. 1073. 1052. 1049. 1025. 1076.  958.  702.  751.  752.]
# 1
# intact acc: 0.53
#
# subject 13, id: bpr0qdsv
# counterbalance cond: 2
# run accuracies, avg RTs:
# [56. 56. 57. 61. 60. 61. 54. 65. 57. 52.] [1139. 1188. 1112. 1100. 1118. 1187. 1145. 1098. 1056. 1182.]
# 2
# intact acc: 0.70
#
# subject 14, id: btc8zumv
# counterbalance cond: 2
# run accuracies, avg RTs:
# [81. 73. 79. 81. 84. 79. 75. 71. 68. 83.] [1146. 1046.  936.  878.  817.  768.  733.  625.  616.  646.]
# 2
# intact acc: 0.89
#
# subject 15, id: cf5j8qak
# counterbalance cond: 1
# run accuracies, avg RTs:
# [77. 78. 80. 90. 79. 84. 80. 77. 78. 74.] [934. 707. 517. 527. 496. 499. 487. 455. 463. 469.]
# 1
# intact acc: 0.94
#
# subject 16, id: cs36fwwf
# counterbalance cond: 2
# run accuracies, avg RTs:
# [49. 52. 55. 29. 53. 50. 46. 55. 46. 56.] [708. 775. 683. 713. 650. 631. 599. 614. 581. 553.]
# 2
# intact acc: 0.53
#
# subject 17, id: dlrwfrmj
# counterbalance cond: 1
# run accuracies, avg RTs:
# [39. 60. 52. 62. 56. 51. 56. 56. 45. 63.] [1153. 1032. 1136. 1273. 1024. 1123. 1048.  975.  790.  827.]
# 1
# intact acc: 0.56
#
# subject 18, id: gmbze47f
# counterbalance cond: 2
# run accuracies, avg RTs:
# [44. 49. 42. 39. 47. 22. 46. 59. 28. 59.] [1146.  963.  976. 1143. 1066.  853.  955.  960. 1107.  990.]
# 2
# intact acc: 0.47
# skipping this subject
#
# subject 19, id: gvfnxm1l
# counterbalance cond: 1
# run accuracies, avg RTs:
# [66. 54. 61. 65. 67. 61. 59. 55. 52. 52.] [1117. 1025.  976. 1054.  908.  936.  881.  879.  880.  771.]
# 1
# intact acc: 0.71
#
# subject 20, id: hiw0y77i
# counterbalance cond: 2
# run accuracies, avg RTs:
# [44. 56. 49. 58. 48. 50. 54. 51. 56. 48.] [ 515.  794. 1273.  142.  108.  124.  181.  204.  187.  108.]
# 2
# intact acc: 0.49
# skipping this subject
#
# subject 21, id: i163wruc
# counterbalance cond: 1
# run accuracies, avg RTs:
# [66. 72. 75. 71. 82. 85. 75. 78. 67. 80.] [747. 838. 858. 887. 775. 837. 843. 844. 870. 883.]
# 1
# intact acc: 0.90
#
# subject 22, id: ibptgp2w
# counterbalance cond: 2
# run accuracies, avg RTs:
# [55. 49. 55. 46. 51. 41. 45. 53. 45. 54.] [954. 948. 905. 902. 757. 935. 875. 710. 662. 696.]
# 2
# intact acc: 0.52
#
# subject 23, id: iuvswbcx
# counterbalance cond: 1
# run accuracies, avg RTs:
# [56. 48. 47. 27. 55. 58. 44. 59. 53. 44.] [961. 663. 847. 771. 733. 834. 741. 764. 746. 712.]
# 1
# intact acc: 0.49
# skipping this subject
#
# subject 24, id: iux5w4wx
# counterbalance cond: 2
# run accuracies, avg RTs:
# [66. 75. 75. 80. 73. 73. 77. 76. 73. 78.] [540. 518. 497. 515. 537. 530. 529. 544. 559. 513.]
# 2
# intact acc: 0.86
#
# subject 25, id: ixs44ht9
# counterbalance cond: 1
# run accuracies, avg RTs:
# [55. 47. 52. 45. 39. 54. 40. 47. 33. 42.] [ 813.  957. 1019.  940. 1057.  999. 1017. 1018. 1107.  913.]
# 1
# intact acc: 0.43
# skipping this subject
#
# subject 26, id: j5q7qpsk
# counterbalance cond: 1
# run accuracies, avg RTs:
# [49. 46. 52. 53. 47. 58. 54. 52. 39. 47.] [756. 996. 984. 921. 908. 817. 860. 767. 759. 601.]
# 1
# intact acc: 0.51
#
# subject 27, id: ktc83wd6
# counterbalance cond: 2
# run accuracies, avg RTs:
# [68. 76. 73. 83. 82. 77. 75. 81. 80. 84.] [635. 637. 662. 645. 787. 821. 740. 608. 648. 678.]
# 2
# intact acc: 0.88
#
# subject 28, id: lbfs1h70
# counterbalance cond: 2
# run accuracies, avg RTs:
# [77. 71. 67. 83. 71. 69. 76. 85. 79. 85.] [1162.  915.  738. 1046. 1071. 1031. 1009. 1041. 1028. 1046.]
# 2
# intact acc: 0.91
#
# subject 29, id: nms43bnl
# counterbalance cond: 2
# run accuracies, avg RTs:
# [40. 45. 46. 57. 56. 46. 52. 45. 49. 49.] [702. 784. 730. 770. 574. 590. 454. 550. 493. 342.]
# 2
# intact acc: 0.52
#
# subject 30, id: p5dfexpc
# counterbalance cond: 2
# run accuracies, avg RTs:
# [74. 71. 74. 68. 63. 69. 69. 71. 61. 74.] [735. 579. 588. 511. 602. 553. 571. 538. 559. 604.]
# 2
# intact acc: 0.78
#
# subject 31, id: p5vspv69
# counterbalance cond: 1
# run accuracies, avg RTs:
# [69. 71. 72. 81. 73. 81. 75. 72. 74. 74.] [756. 768. 686. 663. 588. 588. 636. 601. 579. 605.]
# 1
# intact acc: 0.87
#
# subject 32, id: qqh1odxa
# counterbalance cond: 1
# run accuracies, avg RTs:
# [42. 52. 56.  0. 58. 55. 54. 45. 46. 49.] [868. 809. 886.  nan 820. 863. 882. 792. 782. 876.]
# 1
# intact acc: 0.47
# skipping this subject
#
# subject 33, id: sqrirtq7
# counterbalance cond: 1
# run accuracies, avg RTs:
# [73. 68. 68. 79. 72. 73. 69. 71. 63. 66.] [1037. 1045. 1080. 1187. 1008. 1007. 1020. 1025. 1012.  958.]
# 1
# intact acc: 0.86
#
# subject 34, id: u6ta5l81
# counterbalance cond: 1
# run accuracies, avg RTs:
# [45. 34. 42. 47. 37. 42. 31. 37. 50. 35.] [688. 595. 521. 478. 612. 648. 363. 310. 295. 386.]
# 1
# intact acc: 0.47
# skipping this subject
#
# subject 35, id: x7gqyr98
# counterbalance cond: 1
# run accuracies, avg RTs:
# [47. 53. 51. 39. 48. 46. 14. 26. 46. 47.] [749. 317. 404. 705. 436. 556. 735. 405. 394. 427.]
# 1
# intact acc: 0.41
# skipping this subject
#
# subject 36, id: yg8nw4dz
# counterbalance cond: 1
# run accuracies, avg RTs:
# [60. 68. 71. 72. 77. 77. 75. 62. 66. 68.] [710. 744. 727. 749. 709. 721. 713. 717. 681. 680.]
# 1
# intact acc: 0.81
#
# subject 37, id: zw6ohjae
# counterbalance cond: 1
# run accuracies, avg RTs:
# [53. 57. 54. 57. 57. 64. 49. 44. 51. 40.] [741. 776. 717. 710. 725. 689. 717. 660. 633. 686.]
# 1
# intact acc: 0.56
