# %%
import os, sys
import numpy as np

root = os.path.dirname(os.getcwd())

sys.path.append(os.path.join(root))
from make_expt_designs import make_expt2

# %%
make_expt2.make_trial_info()
# Out:
# making trial info for counterbalance cond 0 of 2
# ['bird', 'drink', 'fruit', 'body_part', 'home_decor', 'medical_equipment', 'weapon', 'vehicle', 'electronic_device', 'sports_equipment']
# proc trial 0 of 1000
# proc trial 100 of 1000
# proc trial 200 of 1000
# proc trial 300 of 1000
# proc trial 400 of 1000
# proc trial 500 of 1000
# proc trial 600 of 1000
# proc trial 700 of 1000
# proc trial 800 of 1000
# proc trial 900 of 1000
# prepping cue names
# checking trial info
# saving to /user_data/mmhender/featsynth/expt_design/expt2/trial_info_counterbal1_randorder0.csv
# proc trial 0 of 1000
# proc trial 100 of 1000
# proc trial 200 of 1000
# proc trial 300 of 1000
# proc trial 400 of 1000
# proc trial 500 of 1000
# proc trial 600 of 1000
# proc trial 700 of 1000
# proc trial 800 of 1000
# proc trial 900 of 1000
# prepping cue names
# checking trial info
# saving to /user_data/mmhender/featsynth/expt_design/expt2/trial_info_counterbal1_randorder1.csv
# ...

# %%
import pandas as pd
for ri in range(11):
    fn2load = os.path.join(root, 'expt_design','expt2','trial_info_counterbal1_randorder%d.csv'%ri)
    t = pd.read_csv(fn2load)
    if ri==0:
        ti = t
    else:
        ti = ti.append(t)

# %%
image_type = 'orig'
cue_level = 'super'
basic_name = 'eye'
inds = (ti['image_type']==image_type) & \
        (ti['cue_level']==cue_level) & \
        (ti['basic_name']==basic_name)

ti[inds]
# Out:
#      trial_num_overall  categ_ind  concept_ind super_name basic_name  ex_num  \
# 710              341.0        3.0          4.0  body_part        eye     1.0
# 540              341.0        3.0          4.0  body_part        eye     1.0
# 240              341.0        3.0          4.0  body_part        eye     1.0
# 168              341.0        3.0          4.0  body_part        eye     1.0
# 785              341.0        3.0          4.0  body_part        eye     1.0
# 754              341.0        3.0          4.0  body_part        eye     1.0
# 409              341.0        3.0          4.0  body_part        eye     1.0
# 847              341.0        3.0          4.0  body_part        eye     1.0
# 824              341.0        3.0          4.0  body_part        eye     1.0
# 206              341.0        3.0          4.0  body_part        eye     1.0
# 452              341.0        3.0          4.0  body_part        eye     1.0
#
# ...

# %%
image_type = 'pool1'
cue_level = 'super'
basic_name = 'eye'
inds = (ti['image_type']==image_type) & \
        (ti['cue_level']==cue_level) & \
        (ti['basic_name']==basic_name)

ti[inds]
# Out:
#      trial_num_overall  categ_ind  concept_ind super_name basic_name  ex_num  \
# 820              343.0        3.0          4.0  body_part        eye     3.0
# 732              343.0        3.0          4.0  body_part        eye     3.0
# 956              343.0        3.0          4.0  body_part        eye     3.0
# 995              343.0        3.0          4.0  body_part        eye     3.0
# 446              343.0        3.0          4.0  body_part        eye     3.0
# 553              343.0        3.0          4.0  body_part        eye     3.0
# 889              343.0        3.0          4.0  body_part        eye     3.0
# 118              343.0        3.0          4.0  body_part        eye     3.0
# 29               343.0        3.0          4.0  body_part        eye     3.0
# 861              343.0        3.0          4.0  body_part        eye     3.0
# 892              343.0        3.0          4.0  body_part        eye     3.0
#
# ...

# %%
ti =
