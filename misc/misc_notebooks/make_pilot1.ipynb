# %%
import numpy as np
import pandas as pd
import os
import sys

import warnings
warnings.filterwarnings('ignore')

# %%
from make_expt_designs import make_pilot1

# %%
make_pilot1.make_trial_info()
# Out:
# making trial info for counterbalance cond 0 of 2
# ['bird', 'drink', 'fruit', 'body_part', 'kitchen_tool', 'plant']
# proc trial 0 of 720
# proc trial 20 of 720
# proc trial 40 of 720
# proc trial 60 of 720
# proc trial 80 of 720
# proc trial 100 of 720
# proc trial 120 of 720
# proc trial 140 of 720
# proc trial 160 of 720
# proc trial 180 of 720
# proc trial 200 of 720
# proc trial 220 of 720
# proc trial 240 of 720
# proc trial 260 of 720
# proc trial 280 of 720
# proc trial 300 of 720
# proc trial 320 of 720
# proc trial 340 of 720
# proc trial 360 of 720
# proc trial 380 of 720
# proc trial 400 of 720
# proc trial 420 of 720
# proc trial 440 of 720
# proc trial 460 of 720
# proc trial 480 of 720
# proc trial 500 of 720
# proc trial 520 of 720
# proc trial 540 of 720
# proc trial 560 of 720
# proc trial 580 of 720
# proc trial 600 of 720
# proc trial 620 of 720
# proc trial 640 of 720
# proc trial 660 of 720
# proc trial 680 of 720
# proc trial 700 of 720
# prepping cue names
# ...

# %%
fn_orig = '/user_data/mmhender/featsynth/expt_design/pilot1/trial_info_counterbal0.csv'
fn_new = '/user_data/mmhender/featsynth/expt_design/pilot1/trial_info_counterbal1.csv'

df = pd.read_csv(fn_orig)
df.to_csv(fn_new)

# %%
project_root = '/user_data/mmhender/featsynth/'

expt_name = 'pilot1'

expt_design_folder = os.path.join(project_root, 'expt_design', expt_name)

for cb in [1,2]:
    
    ti_file = '/user_data/mmhender/featsynth/expt_design/pilot1/trial_info_counterbal%d.csv'%cb

    df = pd.read_csv(ti_file, index_col=0)
    
    var_name = 'info%d'%cb
    
    js_filename = os.path.join(expt_design_folder, 'trialseq_counterbal%d.js'%(cb))

    make_runs_js(df, js_filename, var_name=var_name)

# %%
df
# Out:
#      trial_num_overall  categ_ind  concept_ind        super_name  \
# 0                408.0        3.0          2.0          clothing
# 1                638.0        5.0          1.0     office_supply
# 2                624.0        5.0          1.0     office_supply
# 3                545.0        4.0          3.0  sports_equipment
# 4                582.0        4.0          5.0  sports_equipment
# ..                 ...        ...          ...               ...
# 715               22.0        0.0          1.0            insect
# 716              118.0        0.0          5.0            insect
# 717              558.0        4.0          3.0  sports_equipment
# 718              190.0        1.0          3.0           dessert
# 719               73.0        0.0          3.0            insect
#
#            basic_name  ex_num  image_type_num  \
# 0              jersey     1.0             3.0
# 1    pencil_sharpener     3.0             3.0
# ...

# %%
def make_runs_js(df, js_filename, var_name='info'):

    # the .js file will contain a var "info", 
    # an array where each element is one run. 
    # info[run_number] will be the exact trial sequence that jsPsych needs to do the run.
    
    with open(js_filename,'w') as f:

        f.write('var %s = [\n'%var_name)

        run_numbers = np.unique(np.array(df['run_number']))
        
        for rr in run_numbers:

            ti_thisrun = df.iloc[np.array(df['run_number'])==rr]
            n_trials = ti_thisrun.shape[0]

            f.write('    [\n')
            for tt in range(n_trials):

                trial_info = dict(ti_thisrun.iloc[tt])

                f.write('        {\n')
                for key,val in zip(trial_info.keys(), trial_info.values()):

                    if isinstance(val, str):
                        f.write('        \'%s\': \'%s\',\n'%(key, val))
                    else:
                        f.write('        \'%s\': %d,\n'%(key, val))

                f.write('        },\n')
            f.write('    ],\n')

        f.write('];\n')

# %%
# making .js files for use in jsPsych
# (one file for each run)
run_numbers = np.unique(np.array(trial_info['run_number']))
for rr in run_numbers:
    ti_thisrun = trial_info.iloc[np.array(trial_info['run_number'])==rr]
    js_filename = os.path.join(expt_design_folder, 'trialseq_counterbal%d_run%d.js'%(cb, rr))
    print('saving to %s'%js_filename)
    expt_utils.make_trial_js(ti_thisrun, js_filename, var_name='info')

# %%
# def make_trial_js(df, js_filename, var_name='info'):
df = ti; 
js_filename = '/user_data/mmhender/featsynth/expt_design/pilot1/trial_info_counterbal1_TEST.js'
var_name = 'info'

# %%
with open(js_filename,'w') as f:

    f.write('var %s = [\n'%var_name)
    
    run_numbers = np.unique(np.array(df['run_number']))
    for rr in run_numbers:

        ti_thisrun = df.iloc[np.array(df['run_number'])==rr]
        n_trials = ti_thisrun.shape[0]

        f.write('    [\n')
        for tt in range(n_trials):

            trial_info = dict(ti_thisrun.iloc[tt])

            f.write('        {\n')
            for key,val in zip(trial_info.keys(), trial_info.values()):

                if isinstance(val, str):
                    f.write('        \'%s\': \'%s\',\n'%(key, val))
                else:
                    f.write('        \'%s\': %d,\n'%(key, val))

            f.write('        },\n')
        f.write('    ],\n')
        
    f.write('];\n')

# %%
with open(js_filename,'w') as f:

    
    run_numbers = np.unique(np.array(df['run_number']))
    # for rr in run_numbers:
    for rr in [1]:

        ti_thisrun = df.iloc[np.array(df['run_number'])==rr]
        n_trials = ti_thisrun.shape[0]

        f.write('var %s%d = [\n'%(var_name,rr))
    
        # f.write('    \'run%d\': [\n'%rr)
        for tt in range(n_trials):

            trial_info = dict(df.iloc[tt])

            f.write('    {\n')
            for key,val in zip(trial_info.keys(), trial_info.values()):

                if isinstance(val, str):
                    f.write('    \'%s\': \'%s\',\n'%(key, val))
                else:
                    f.write('    \'%s\': %d,\n'%(key, val))

            f.write('    },\n')
        f.write('    ];\n')
        
    # f.write('};\n')

# %%
things_root = '/user_data/mmhender/things/'
concepts_filename = os.path.join(things_root, 'concepts_use.npy')
concepts_use = np.load(concepts_filename,allow_pickle=True).item()
categ_names = concepts_use['categ_names']
concept_names = concepts_use['concept_names_subsample']
image_names = concepts_use['image_names']

# %%
for kk in image_names.keys():
    image_names[kk] = image_names[kk][0:4]

# %%
image_names
# Out:
# {'cardinal': ['cardinal_01b.jpg',
#   'cardinal_02s.jpg',
#   'cardinal_03s.jpg',
#   'cardinal_04s.jpg'],
#  'chick': ['chick_01b.jpg', 'chick_02s.jpg', 'chick_03s.jpg', 'chick_04s.jpg'],
#  'cockatoo': ['cockatoo_01b.jpg',
#   'cockatoo_02s.jpg',
#   'cockatoo_03s.jpg',
#   'cockatoo_04s.jpg'],
#  'crow': ['crow_01b.jpg', 'crow_02s.jpg', 'crow_03s.jpg', 'crow_04s.jpg'],
#  'duck': ['duck_01b.jpg', 'duck_02s.jpg', 'duck_03s.jpg', 'duck_04s.jpg'],
#  'duckling': ['duckling_01b.jpg',
#   'duckling_02s.jpg',
#   'duckling_03s.jpg',
#   'duckling_04s.jpg'],
#  'eagle': ['eagle_01b.jpg', 'eagle_02s.jpg', 'eagle_03s.jpg', 'eagle_04s.jpg'],
#  'flamingo': ['flamingo_01b.jpg',
#   'flamingo_02s.jpg',
#   'flamingo_03s.jpg',
#   'flamingo_04s.jpg'],
#  'goose': ['goose_01b.jpg', 'goose_02s.jpg', 'goose_03s.jpg', 'goose_04s.jpg'],
#  'hawk': ['hawk_01b.jpg', 'hawk_02s.jpg', 'hawk_03s.jpg', 'hawk_04s.jpg'],
#  'hummingbird': ['hummingbird_01b.jpg',
#   'hummingbird_02s.jpg',
# ...

# %%
things_root = '/user_data/mmhender/things/'
rndseed = 456466

# %%
categ_sets, concept_sets, image_name_sets = choose_image_subsets()
categ_sets[0]
# Out:
# ['bird', 'drink', 'fruit', 'body_part', 'kitchen_tool', 'plant']

# %%
n_categ_use = len(categ_sets[0])
n_concepts_use = len(concept_sets[0][0])
n_ex_use = len(image_name_sets[0][0][0])

# %%
n_ex_use
# Out:
# 4

# %%
categ_inds_set1 = [np.where(categ_)

# %%
categ_inds_use = np.random.choice(np.arange(len(categ_names)), n_categ_use, replace=False)
categ_use = np.array(categ_names)[categ_inds_use]
print(categ_use)
concepts_use = [np.random.choice(concept_names[ca], n_concepts_use, replace=False) for ca in categ_inds_use]
image_names_use = [[np.random.choice(image_names[co], n_ex_use, replace=False) for co in conc] \
                   for conc in concepts_use]
# Out:
# ['kitchen_tool' 'plant' 'sports_equipment' 'office_supply' 'vehicle'
#  'electronic_device']

# %%
image_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2f07779501ba> in <module>
# ----> 1 image_names
#
# NameError: name 'image_names' is not defined

# %%
[len(conc) for conc in concept_names]
# Out:
# [12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12]

# %%
len(categ_names)
# Out:
# 21

# %%
categ_names
# Out:
# ['bird',
#  'body_part',
#  'clothing',
#  'dessert',
#  'drink',
#  'electronic_device',
#  'fruit',
#  'furniture',
#  'home_decor',
#  'insect',
#  'kitchen_tool',
#  'medical_equipment',
#  'musical_instrument',
#  'office_supply',
#  'part_of_car',
#  'plant',
#  'sports_equipment',
#  'toy',
#  'vegetable',
#  'vehicle',
#  'weapon']

# %%
n_trials_total = n_categ_use * n_concepts_use * n_ex_use * n_image_types
n_trials_total
# Out:
# 720

# %%
n_resp_conds = 2;

# image types are original or "synth" from different DNN layers
n_layers=4
n_image_types = n_layers+1 

n_trials_total = n_categ_use * n_concepts_use * n_ex_use * n_image_types

n_runs = 8;
assert(np.mod(n_trials_total, n_runs)==0)
n_trials_per_run = int(n_trials_total/n_runs);

# %%
20*24
# Out:
# 480

# %%
concept_names
# Out:
# [array(['toucan', 'ostrich', 'chick', 'pigeon', 'turkey', 'duck', 'eagle',
#         'parrot', 'vulture', 'seagull', 'pelican', 'peacock'], dtype='<U18'),
#  array(['thumb', 'leg', 'skin', 'arm', 'wrist', 'elbow', 'ear', 'tongue',
#         'shoulder', 'hair', 'eye', 'mouth'], dtype='<U18'),
#  array(['jumpsuit', 'blazer', 'shorts', 'pantyhose', 'jersey',
#         'fishnet_stockings', 'underwear', 'cape', 'turtleneck', 'pantsuit',
#         'sweatsuit', 'cardigan'], dtype='<U18'),
#  array(['souffle', 'popsicle', 'birthday_cake', 'donut', 'tiramisu',
#         'baklava', 'brownie', 'whipped_cream', 'creme_brulee', 'chocolate',
#         'mousse', 'pudding'], dtype='<U18'),
#  array(['espresso', 'tea', 'milk', 'eggnog', 'hot_chocolate', 'smoothie',
#         'lemonade', 'juice', 'latte', 'wine', 'soda', 'champagne'],
#        dtype='<U18'),
#  array(['stereo', 'television', 'tablet', 'computer_screen', 'radio',
#         'remote_control', 'modem', 'cellphone', 'tape_recorder',
# ...

# %%
categ_names
# Out:
# ['bird',
#  'body_part',
#  'clothing',
#  'dessert',
#  'drink',
#  'electronic_device',
#  'fruit',
#  'furniture',
#  'home_decor',
#  'insect',
#  'kitchen_tool',
#  'medical_equipment',
#  'musical_instrument',
#  'office_supply',
#  'part_of_car',
#  'plant',
#  'sports_equipment',
#  'toy',
#  'vegetable',
#  'vehicle',
#  'weapon']

# %%
ti = pd.read_csv('/user_data/mmhender/featsynth/expt_design/pilot1/trial_info.csv')
ti
# Out:
#      trial_num_overall  categ_ind  concept_ind     super_name   basic_name  \
# 0                177.0        1.0          2.0      body_part        elbow
# 1                186.0        1.0          3.0      body_part          arm
# 2                274.0        2.0          1.0          fruit       banana
# 3                211.0        1.0          4.0      body_part     shoulder
# 4                 59.0        0.0          2.0  office_supply       eraser
# ..                 ...        ...          ...            ...          ...
# 475              101.0        0.0          5.0  office_supply       staple
# 476                7.0        0.0          0.0  office_supply  paperweight
# 477              440.0        3.0          4.0           bird      peacock
# 478              466.0        3.0          5.0           bird       toucan
# 479               54.0        0.0          2.0  office_supply       eraser
#
# ...

# %%
def make_run_js_files(df, expt_name):
    
    run_numbers = np.unique(np.array(df['run_number']))
    
    for rr in run_numbers:

        ti_thisrun = ti.iloc[np.array(ti['run_number'])==rr]
        expt_design_folder = os.path.join(project_root, 'expt_design', expt_name)
        js_filename = os.path.join(expt_design_folder, 'trialseq_run%d.js'%rr)
        print('saving to %s'%js_filename)
        expt_utils.make_trial_js(ti_thisrun, js_filename, var_name='info')

# %%
from code_utils import expt_utils

# %%
project_root = '/user_data/mmhender/featsynth/'
make_run_js_files(ti, 'pilot1')
# Out:
# saving to /user_data/mmhender/featsynth/expt_design/pilot1/trialseq_run1.js
# saving to /user_data/mmhender/featsynth/expt_design/pilot1/trialseq_run2.js
# saving to /user_data/mmhender/featsynth/expt_design/pilot1/trialseq_run3.js
# saving to /user_data/mmhender/featsynth/expt_design/pilot1/trialseq_run4.js
# saving to /user_data/mmhender/featsynth/expt_design/pilot1/trialseq_run5.js
# saving to /user_data/mmhender/featsynth/expt_design/pilot1/trialseq_run6.js
# saving to /user_data/mmhender/featsynth/expt_design/pilot1/trialseq_run7.js
# saving to /user_data/mmhender/featsynth/expt_design/pilot1/trialseq_run8.js
# saving to /user_data/mmhender/featsynth/expt_design/pilot1/trialseq_run9.js
# saving to /user_data/mmhender/featsynth/expt_design/pilot1/trialseq_run10.js
# saving to /user_data/mmhender/featsynth/expt_design/pilot1/trialseq_run11.js
# saving to /user_data/mmhender/featsynth/expt_design/pilot1/trialseq_run12.js

# %%
for rr in np.arange(1,13):

    ti_thisrun = ti.iloc[np.array(ti['run_number'])==rr]
    expt_design_folder = os.path.join(project_root, 'expt_design')
    js_filename = os.path.join(expt_design_folder, 'trialseq_run%d.js'%rr)
    make_trial_js(ti_thisrun, js_filename, var_name='info')

# %%
for rr in np.arange(1,2):

    ti_thisrun = ti.iloc[np.array(ti['run_number'])==rr]
    ti_thisrun['image_name'].iloc[np.arange(0,100,2)] = 'dollhouse_02s_grid5_1x1_upto_pool4.png'
    ti_thisrun['image_name'].iloc[np.arange(1,100,2)] = 'cape_04s_grid5_1x1_upto_pool3.png'
    expt_design_folder = os.path.join(project_root, 'expt_design')
    js_filename = os.path.join(expt_design_folder, 'trialseq_TEST_run%d.js'%rr)
    make_trial_js(ti_thisrun, js_filename, var_name='info')

# %%
ti_thisrun
# Out:
#     trial_num_overall  categ_ind  concept_ind     super_name   basic_name  \
# 0               709.0        5.0          5.0            toy    dollhouse
# 1               978.0        8.0          0.0       clothing         cape
# 2               779.0        6.0          2.0        dessert      baklava
# 3              1059.0        8.0          4.0       clothing     pantsuit
# 4              1133.0        9.0          2.0      vegetable      arugula
# ..                ...        ...          ...            ...          ...
# 95             1034.0        8.0          3.0       clothing     jumpsuit
# 96             1039.0        8.0          3.0       clothing     jumpsuit
# 97             1162.0        9.0          4.0      vegetable         kale
# 98             1146.0        9.0          3.0      vegetable      rhubarb
# 99               13.0        0.0          0.0  office_supply  paperweight
#
#     ex_num  image_type_num                              image_name  \
# ...

# %%
def make_trial_js(df, js_filename, var_name='info'):
    
    n_trials = df.shape[0]

    with open(js_filename,'w') as f:

        f.write('var %s = [\n'%var_name)

        for tt in range(n_trials):
            
            trial_info = dict(df.iloc[tt])

            f.write('    {\n')
            for key,val in zip(trial_info.keys(), trial_info.values()):

                if isinstance(val, str):
                    f.write('    \'%s\': \'%s\',\n'%(key, val))
                else:
                    f.write('    \'%s\': %d,\n'%(key, val))

            f.write('    },\n')

        f.write('];\n')

# %%
url = get_shared_url(path = '/images/aloe_02s/orig.png')
url
# Out:
# 'https://dl.dropboxusercontent.com/s/2mdxubcv6biu9sk/orig.png?dl=0'
