# %%
from make_expt_designs import make_expt1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3931/1597416233.py in <module>
# ----> 1 from make_expt_designs import make_expt1
#
# ModuleNotFoundError: No module named 'make_expt_designs'

# %%
import os, sys
os.chdir('/user_data/mmhender/featsynth/make_expt_designs/')
sys.path.append('/user_data/mmhender/featsynth/code_utils/')
sys.path.append('/user_data/mmhender/featsynth/')

# %%
import make_expt1

# %%
make_expt1.make_trial_info()
# Out:
# making trial info for counterbalance cond 0 of 2
# ['bird', 'drink', 'fruit', 'body_part', 'home_decor', 'medical_equipment', 'weapon', 'vehicle', 'electronic_device', 'sports_equipment']
# proc trial 0 of 1000
# /images_v1/peacock_01b/orig.png
# /images_v1/peacock_02s/orig.png
# /images_v1/peacock_03s/grid5_1x1_upto_pool1.png
# /images_v1/peacock_04s/grid5_1x1_upto_pool1.png
# /images_v1/peacock_05s/grid5_1x1_upto_pool2.png
# /images_v1/peacock_06s/grid5_1x1_upto_pool2.png
# /images_v1/peacock_07s/grid5_1x1_upto_pool3.png
# /images_v1/peacock_08s/grid5_1x1_upto_pool3.png
# /images_v1/peacock_09s/grid5_1x1_upto_pool4.png
# /images_v1/peacock_10s/grid5_1x1_upto_pool4.png
# /images_v1/eagle_01b/orig.png
# /images_v1/eagle_02s/orig.png
# /images_v1/eagle_03s/grid5_1x1_upto_pool1.png
# /images_v1/eagle_04s/grid5_1x1_upto_pool1.png
# /images_v1/eagle_05s/grid5_1x1_upto_pool2.png
# /images_v1/eagle_06s/grid5_1x1_upto_pool2.png
# /images_v1/eagle_07s/grid5_1x1_upto_pool3.png
# ...
